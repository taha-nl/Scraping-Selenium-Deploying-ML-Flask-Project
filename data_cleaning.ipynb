# %% [markdown]
# # importing libraries

# %%
#### importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### loading data

# %%
glassdoor_df=pd.read_csv("glassdoor_jobs_.csv")
df=glassdoor_df.copy()

# %%
df.sample(10)
# Out:
#      Unnamed: 0                                          Job Title  \
# 710         710                                      Data Engineer
# 608         608                                 Lead Data Engineer
# 807         807                               Senior Data Engineer
# 50           50                             Associate Data Analyst
# 528         528  Senior Scientist - Toxicologist - Product Inte...
# 55           55             Data Scientist, Office of Data Science
# 600         600                                       Data Analyst
# 333         333                              Senior Data Scientist
# 52           52  College Hire - Data Scientist - Open to Decemb...
# 90           90                                     Data Scientist
#
#                   Salary Estimate  \
# 710                            -1
# 608    $190K-$220K(Employer est.)
# 807  $100K-$173K (Glassdoor est.)
# 50     $20K-$39K (Glassdoor est.)
# 528   $47K-$101K (Glassdoor est.)
# ...

# %%
df.shape
# Out:
# (956, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         956 non-null    int64
#  1   Job Title          956 non-null    object
#  2   Salary Estimate    956 non-null    object
#  3   Job Description    956 non-null    object
#  4   Rating             956 non-null    float64
#  5   Company Name       956 non-null    object
#  6   Location           956 non-null    object
#  7   Headquarters       956 non-null    object
#  8   Size               956 non-null    object
#  9   Founded            956 non-null    int64
#  10  Type of ownership  956 non-null    object
#  11  Industry           956 non-null    object
#  12  Sector             956 non-null    object
#  13  Revenue            956 non-null    object
#  14  Competitors        956 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# dtype: int64

# %% [markdown]
# ###  salary parsing

# %%
(df["Salary Estimate"]=="-1").sum()
# Out:
# 214

# %%
df=df[df["Salary Estimate"]!="-1"]

# %%
df["Salary Estimate"].sample(10)
# Out:
# 694    Employer Provided Salary:$25-$28 Per Hour
# 856                   $39K-$66K (Glassdoor est.)
# 463                   $56K-$99K (Glassdoor est.)
# 413                  $85K-$140K (Glassdoor est.)
# 243                  $81K-$167K (Glassdoor est.)
# 721                   $43K-$77K (Glassdoor est.)
# 556                  $65K-$106K (Glassdoor est.)
# 73                    $60K-$99K (Glassdoor est.)
# 758                  $74K-$137K (Glassdoor est.)
# 39                  $115K-$180K (Glassdoor est.)
# Name: Salary Estimate, dtype: object

# %%
df["Salary Estimate"].sample(30)
# Out:
# 784     $65K-$126K (Glassdoor est.)
# 920      $49K-$97K (Glassdoor est.)
# 234     $54K-$115K (Glassdoor est.)
# 442      $42K-$86K (Glassdoor est.)
# 318    $116K-$194K (Glassdoor est.)
# 109      $40K-$73K (Glassdoor est.)
# 631     $55K-$105K (Glassdoor est.)
# 28       $34K-$61K (Glassdoor est.)
# 430      $43K-$86K (Glassdoor est.)
# 604     $80K-$139K (Glassdoor est.)
# 799    $113K-$182K (Glassdoor est.)
# 904    $102K-$172K (Glassdoor est.)
# 476     $68K-$114K (Glassdoor est.)
# 20      $81K-$130K (Glassdoor est.)
# 752      $44K-$73K (Glassdoor est.)
# 89       $37K-$76K (Glassdoor est.)
# 645     $81K-$167K (Glassdoor est.)
# 162     $80K-$120K (Glassdoor est.)
# 191    $110K-$175K (Glassdoor est.)
# 124    $121K-$193K (Glassdoor est.)
# 72      $88K-$148K (Glassdoor est.)
# 829      $49K-$85K (Glassdoor est.)
# 600      $50K-$92K (Glassdoor est.)
# 488     $65K-$110K (Glassdoor est.)
# 230     $90K-$179K (Glassdoor est.)
# 883     $79K-$147K (Glassdoor est.)
# ...

# %%
df["hourly"]=df["Salary Estimate"].apply(lambda x:1 if "per hour" in x.lower() else 0)

# %%
df["employer_provided"]=df["Salary Estimate"].apply(lambda x:1 if "employer provided salary" in x.lower() else 0)

# %%
df.sample(10)
# Out:
#      Unnamed: 0                              Job Title  \
# 507         507  Sr Software Engineer (Data Scientist)
# 608         608                     Lead Data Engineer
# 330         330                         Data Scientist
# 828         828             Senior Risk Data Scientist
# 199         199      Scientist, Analytical Development
# 848         848        Senior Scientist (Neuroscience)
# 212         212         Excel / VBA / SQL Data Analyst
# 30           30                         Data Scientist
# 750         750                   Senior Data Engineer
# 217         217                     Radar Data Analyst
#
#                   Salary Estimate  \
# 507   $81K-$140K (Glassdoor est.)
# 608    $190K-$220K(Employer est.)
# 330   $70K-$122K (Glassdoor est.)
# 828  $107K-$172K (Glassdoor est.)
# 199    $42K-$82K (Glassdoor est.)
# 848  $109K-$200K (Glassdoor est.)
# 212    $44K-$78K (Glassdoor est.)
# 30     $80K-$90K (Glassdoor est.)
# 750   $97K-$180K (Glassdoor est.)
# ...

# %%
salary=df["Salary Estimate"].str.split("(").apply(lambda x:x[0].replace("$","").replace("K",""))

# %%
salary
# Out:
# 0       53-91
# 1      63-112
# 2       80-90
# 3       56-97
# 4      86-143
#         ...
# 950    58-111
# 951    72-133
# 952     56-91
# 953    95-160
# 955    61-126
# Name: Salary Estimate, Length: 742, dtype: object

# %%
df["min_salary"]=df
